# %% [markdown]
# <a href="https://colab.research.google.com/github/mreedu/projects/blob/main/Copy_of_Payoff_graphs_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRODUCTION TO OPTIONS**

# %% [markdown]
# [Basics of options](https://corporatefinanceinstitute.com/resources/derivatives/options-calls-and-puts/)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.32)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.10)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.11.17)

# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from datetime import date


import warnings
warnings.filterwarnings("ignore")

# to fetch data
import yfinance as yf

# %% [markdown]
# **IMPORTING DATA FOR OPTIONS**

# %%
symbol = '^SPX'  #the ticker of the stock whose data is to be taken out
dfo = yf.Ticker(symbol)

# %%
dfo.options  #to get the date of different expiration time
# Out:
# ('2023-12-13',
#  '2023-12-14',
#  '2023-12-15',
#  '2023-12-18',
#  '2023-12-19',
#  '2023-12-20',
#  '2023-12-21',
#  '2023-12-22',
#  '2023-12-26',
#  '2023-12-27',
#  '2023-12-28',
#  '2023-12-29',
#  '2024-01-02',
#  '2024-01-03',
#  '2024-01-04',
#  '2024-01-05',
#  '2024-01-08',
#  '2024-01-09',
#  '2024-01-10',
#  '2024-01-11',
#  '2024-01-12',
#  '2024-01-16',
#  '2024-01-19',
#  '2024-01-22',
#  '2024-01-26',
#  '2024-01-29',
#  '2024-01-31',
#  '2024-02-02',
#  '2024-02-05',
#  '2024-02-16',
#  '2024-02-29',
#  '2024-03-15',
#  '2024-03-28',
#  '2024-04-19',
#  '2024-04-30',
#  '2024-05-17',
#  '2024-05-31',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-09-30',
#  '2024-10-18',
#  '2024-11-15',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19',
#  '2026-03-20',
#  '2026-12-18',
#  '2027-12-17',
#  '2028-12-15')

# %%
dfo_exp = dfo.option_chain(dfo.options[1])    #to get data of next recent expiry date

# %%
dfo_exp.calls #Data for call options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPXW231214C01200000 2023-11-02 14:08:17+00:00  1200.0    3079.70  3390.6
# 1    SPXW231214C02400000 2023-11-14 17:20:26+00:00  2400.0    2095.05  2249.2
# 2    SPXW231214C03000000 2023-11-08 17:44:57+00:00  3000.0    1377.53  1602.8
# 3    SPXW231214C03500000 2023-11-06 21:07:56+00:00  3500.0     878.13  1051.9
# 4    SPXW231214C04000000 2023-12-08 16:29:00+00:00  4000.0     589.16   649.5
# ..                   ...                       ...     ...        ...     ...
# 112  SPXW231214C05000000 2023-12-11 17:49:56+00:00  5000.0       0.10     0.0
# 113  SPXW231214C05100000 2023-12-01 19:40:40+00:00  5100.0       0.10     0.0
# 114  SPXW231214C05200000 2023-11-29 14:31:37+00:00  5200.0       0.07     0.0
# 115  SPXW231214C05400000 2023-12-08 19:35:08+00:00  5400.0       0.05     0.0
# 116  SPXW231214C05600000 2023-11-29 14:30:06+00:00  5600.0       0.05     0.0
#
#          ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    3405.30     0.0            0.0     NaN            14           0.000010
# 1    2250.30     0.0            0.0     NaN             1           4.181279
# 2    1609.20     0.0            0.0     NaN             9           0.000010
# 3    1058.10     0.0            0.0     NaN             5           0.000010
# 4     650.60     0.0            0.0     2.0           517           1.166447
# ..       ...     ...            ...     ...           ...                ...
# 112     0.05     0.0            0.0    10.0           812           0.335944
# 113     0.05     0.0            0.0    11.0           911           0.416021
# 114     0.05     0.0            0.0    10.0            74           0.494146
# 115     0.05     0.0            0.0    10.0            29           0.609379
# 116     0.05     0.0            0.0     NaN             5           0.746096
#
#      inTheMoney contractSize currency
# 0          True      REGULAR      USD
# 1          True      REGULAR      USD
# 2          True      REGULAR      USD
# 3          True      REGULAR      USD
# 4          True      REGULAR      USD
# ..          ...          ...      ...
# 112       False      REGULAR      USD
# 113       False      REGULAR      USD
# 114       False      REGULAR      USD
# 115       False      REGULAR      USD
# 116       False      REGULAR      USD
#
# [117 rows x 14 columns]

# %%
dfo_exp.puts #Data for put options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW231214P01200000 2023-11-02 14:08:17+00:00  1200.0       0.03    0.0
# 1    SPXW231214P01800000 2023-10-31 13:32:12+00:00  1800.0       0.15    0.0
# 2    SPXW231214P02000000 2023-11-08 15:03:16+00:00  2000.0       0.07    0.0
# 3    SPXW231214P02200000 2023-11-14 15:50:16+00:00  2200.0       0.05    0.0
# 4    SPXW231214P02400000 2023-11-14 17:20:26+00:00  2400.0       0.10    0.0
# ..                   ...                       ...     ...        ...    ...
# 140  SPXW231214P04900000 2023-11-14 16:06:02+00:00  4900.0     384.22  249.3
# 141  SPXW231214P05000000 2023-12-11 20:10:54+00:00  5000.0     379.46  349.3
# 142  SPXW231214P05200000 2023-12-11 21:03:04+00:00  5200.0     575.42  549.3
# 143  SPXW231214P05400000 2023-11-14 16:02:12+00:00  5400.0     882.00  749.2
# 144  SPXW231214P05600000 2023-11-14 16:00:43+00:00  5600.0    1081.70  949.2
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0      0.10     0.0            0.0     NaN            14           5.203128
# 1      0.00     0.0            0.0     3.0             3           0.500005
# 2      0.05     0.0            0.0     2.0             5           3.140627
# 3      0.05     0.0            0.0     1.0             3           2.796878
# 4      0.05     0.0            0.0     NaN             1           2.484379
# ..      ...     ...            ...     ...           ...                ...
# 140  250.50     0.0            0.0     NaN            42           0.000010
# 141  350.40     0.0            0.0    18.0           517           0.000010
# 142  550.40     0.0            0.0     4.0             4           0.000010
# 143  750.40     0.0            0.0    44.0            36           0.000010
# 144  950.30     0.0            0.0     NaN             1           0.000010
#
#      inTheMoney contractSize currency
# 0         False      REGULAR      USD
# 1         False      REGULAR      USD
# 2         False      REGULAR      USD
# 3         False      REGULAR      USD
# 4         False      REGULAR      USD
# ..          ...          ...      ...
# 140        True      REGULAR      USD
# 141        True      REGULAR      USD
# 142        True      REGULAR      USD
# 143        True      REGULAR      USD
# 144        True      REGULAR      USD
#
# [145 rows x 14 columns]

# %%
#run this tab to make you aware of the latest price of apple stock

symbol = '^SPX'
end = date.today()
start = end.replace(year = 2022)


# Read data
df = yf.download(symbol,start,end)

df.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-12-06  4586.229980  4590.740234  4546.500000  4549.339844  4549.339844
# 2023-12-07  4568.839844  4590.919922  4565.220215  4585.589844  4585.589844
# 2023-12-08  4576.200195  4609.229980  4574.060059  4604.370117  4604.370117
# 2023-12-11  4593.390137  4623.709961  4593.390137  4622.439941  4622.439941
# 2023-12-12  4618.299805  4643.930176  4608.089844  4643.700195  4643.700195
#
#                 Volume
# Date
# 2023-12-06  4245680000
# 2023-12-07  3818880000
# 2023-12-08  3707010000
# 2023-12-11  3823210000
# 2023-12-12  3808380000

# %% [markdown]
# # **PAYOFF FROM CALL AND PUT OPTIONS**

# %% [markdown]
# # **Call option**
# payoff=max(-C, S - X - C)

# %% [markdown]
# # **Put option**
# payoff=max(-P, X - S - P)
#
# P and C are premiums of calls and puts
#
# S is the stock price
#
# X is the strike price

# %%
def payoff(option_type, premium, S, X):
  payoff =0
  if option_type.upper() == 'C':
   payoff = np.maximum(-premium,S-X-premium)
  elif option_type.upper() == 'P':
   payoff = np.maximum(-premium,X-S-premium)
  else:
    print("Option type not supported")
    return None
  return payoff




  #your code here

# %% [markdown]
# Checking the output of payoff function

# %%
payoff('C', 10, 120,100)  #answer displayed should be 10
# Out:
# 10

# %%
payoff('Z', 10, 120, 100)  #answer displayed should be option type not supported
# Out:
# Option type not supported

# %%
payoff('P', 10, 120, 100)  #answer displayed should be -10
# Out:
# -10

# %% [markdown]
# # **PAYOFF GRAPHS**

# %% [markdown]
# **CALL OPTION**

# %%
X = dfo_exp.calls['strike'][0]
premium = dfo_exp.calls['lastPrice'][0]

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('C', premium, i, X) for i in StockPrice]

# %%
#PLOTTING THE PAYOFF GRAPH FOR CALL OPTION
plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Call option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0 or S=X+C
plt.plot(X+premium, 0,'ro', label = 'breakeven point')
plt.legend()

# %% [markdown]
# **PUT OPTION**

# %%
X = dfo_exp.puts['strike'][len(dfo_exp.puts)-1]
premium = dfo_exp.puts['lastPrice'][len(dfo_exp.puts)-1]
# Out:
# 1081.7

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('P', premium, i, X) for i in StockPrice]

#Payoff = #your code here

# %%
#PLOTTING THE PAYOFF GRAPH FOR PUT OPTION
plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Put option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0 or S=X-P
plt.plot(X-premium, 0,'ro', label = 'breakeven point')
plt.legend()

#your code here
